# %% [markdown]
# # Projeto do curso de Python para Análise de Dados
# ## Projeto 05 - Case RH

# %%
# Modeling Librarys
import numpy as np
import pandas as pd

# DataViz Librarys
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('Dados_Pib.xlsx')
data.head()
# Out:
#   Territorialidades   Ano  PIB per capita
# 0            Brasil  2013           22.20
# 1              Acre  2013           12.37
# 2           Alagoas  2013            9.45
# 3             Amapá  2013           14.53
# 4          Amazonas  2013           18.25

# %%
data.shape
# Out:
# (112, 3)

# %%
data.columns
# Out:
# Index(['Territorialidades', 'Ano', 'PIB per capita'], dtype='object')

# %% [markdown]
# ### Missing data

# %%
data.isnull().sum()
# Out:
# Territorialidades    0
# Ano                  0
# PIB per capita       0
# dtype: int64

# %%
# No data is missing....
sns.heatmap(data.isnull(),cbar = False)

# %% [markdown]
# ### Exploratory Analysis

# %%
data.groupby(by = ['Territorialidades','Ano']).mean()
# Out:
#                         PIB per capita
# Territorialidades Ano
# Acre              2013           12.37
#                   2014           13.41
#                   2015           12.24
#                   2016           11.18
# Alagoas           2013            9.45
# ...                                ...
# São Paulo         2016           30.24
# Tocantins         2013           13.47
#                   2014           13.77
#                   2015           13.79
#                   2016           13.68
#
# [112 rows x 1 columns]

# %% [markdown]
# ### Grid System

# %%
# Grid System

# Seaborn Style
sns.set_style("white")

# Background collor
back_collor = '#f5f5f5'

# buildind the Grid System
grid_graphic = sns.FacetGrid(data, col= 'Territorialidades', hue = 'Territorialidades', col_wrap= 5 )

# Ploting graphics
grid_graphic = grid_graphic.map(plt.plot, 'Ano', 'PIB per capita')

# Adding shadow + title adjustment
grid_graphic = grid_graphic.map(plt.fill_between, 'Ano', 'PIB per capita',alpha = 0.2).set_titles('{col_name} Territorialidades')

# Filtering titles
grid_graphic = grid_graphic.set_titles('{col_name}')


# Title
grid_graphic = grid_graphic.fig.suptitle('GDP Analysis by State',fontsize = 24, weight = 'bold',x = 0.5, y =1.03 )


plt.show()
