# %% [markdown]
# # Projeto do curso de Python para Análise de Dados
# ## Projeto 05 - Case RH

# %%
# Modeling Librarys
import numpy as np
import pandas as pd

# DataViz Librarys
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Salary_Data.csv')
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.shape
# Out:
# (30, 2)

# %%
data.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %% [markdown]
# ### Missing Data

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
# No data is missing....
sns.heatmap(data.isnull(),cbar = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Exploratory Analysis

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(7,6))
plt.title('Salary Analysis')
sns.kdeplot(data['Salary'],color = 'Red')
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(7,6))
plt.title('Experience Analysis')
sns.kdeplot(data['YearsExperience'],color = 'Blue')
plt.show()

# %%
sns.set_style("ticks")
plt.figure(figsize=(10,5))
sns.boxenplot(data['Salary'])
plt.show()
# Out:
# c:\Users\mazza\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set_style("ticks")
plt.figure(figsize=(10,5))
sns.boxenplot(data['YearsExperience'])
plt.show()
# Out:
# c:\Users\mazza\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=data, x = 'Salary', y = 'YearsExperience')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.regplot(data=data, x = 'Salary', y = 'YearsExperience')
plt.show()

# %%
correlacao_pearson = data.corr('pearson')
plt.figure(figsize=(10,5))
sns.heatmap(correlacao_pearson,annot=True,cbar = False)
# Out:
# <AxesSubplot:>

# %%
correlacao_spearman = data.corr('spearman')
plt.figure(figsize=(10,5))
sns.heatmap(correlacao_spearman,annot=True,cbar = False)
# Out:
# <AxesSubplot:>
