# %% [markdown]
# # Projeto do curso de Python para Análise de Dados
# ## Project 08 - Energy Companies

# %%
# Modeling Librarys
import numpy as np
import pandas as pd

# DataViz Librarys
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('Dados_Empresas_Energia.xlsx')
data.head()
# Out:
#         Data  Petrobras  Aeris Energy     Alupar  AES Brasil      Cemig  \
# 0 2021-03-22  23.080000          9.28  24.600000       31.10  11.040665
# 1 2021-03-23  22.549999          8.94  24.910000       30.75  11.040665
# 2 2021-03-24  22.530001          9.02  24.610001       30.00  10.816444
# 3 2021-03-25  22.959999          9.20  24.990000       30.77  11.157260
# 4 2021-03-26  23.299999          9.10  25.299999       30.27  11.148292
#
#         Cesp
# 0  27.980000
# 1  27.700001
# 2  27.330000
# 3  27.809999
# 4  28.090000

# %%
data.shape
# Out:
# (251, 7)

# %%
data.columns
# Out:
# Index(['Data', 'Petrobras', 'Aeris Energy', 'Alupar', 'AES Brasil', 'Cemig',
#        'Cesp'],
#       dtype='object')

# %% [markdown]
# ### Seting index

# %%
data.set_index('Data',inplace=True)
data.head()
# Out:
#             Petrobras  Aeris Energy     Alupar  AES Brasil      Cemig  \
# Data
# 2021-03-22  23.080000          9.28  24.600000       31.10  11.040665
# 2021-03-23  22.549999          8.94  24.910000       30.75  11.040665
# 2021-03-24  22.530001          9.02  24.610001       30.00  10.816444
# 2021-03-25  22.959999          9.20  24.990000       30.77  11.157260
# 2021-03-26  23.299999          9.10  25.299999       30.27  11.148292
#
#                  Cesp
# Data
# 2021-03-22  27.980000
# 2021-03-23  27.700001
# 2021-03-24  27.330000
# 2021-03-25  27.809999
# 2021-03-26  28.090000

# %% [markdown]
# ### Missing Data

# %%
data.isnull().sum()
# Out:
# Petrobras       0
# Aeris Energy    0
# Alupar          0
# AES Brasil      0
# Cemig           0
# Cesp            0
# dtype: int64

# %%
# No data is missing....
sns.heatmap(data.isnull(),cbar = False);

# %% [markdown]
# ### Exploratory Analysis

# %%
import random
def random_color():
    levels = range(32,256,32)
    return tuple(random.choice(levels) for _ in range(3))

# %%
# graphic

# Style
plt.style.use('seaborn-darkgrid')

# Size
plt.figure(figsize=(20,8))

# Title
plt.title('Brazilian Energy Companies Analysis', fontsize = 20, weight = 'bold')

# Plot Petrobras
plt.plot(data.index,data.Petrobras, color = '#008c4a', linewidth = 2)

# Petrobras text
plt.text(data.index[-1],data['Petrobras'].tail(1), 'Petrobras', color = '#008c4a', size = 'large', horizontalalignment = 'left')

# labels
plt.xlabel('Period', fontsize = 14)
plt.ylabel('Closing Price (R$)', fontsize = 14)

# All columns plot
for column in data.columns[1:]:
    # Plot all columns
    plt.plot(data.index,data[column], color = 'gray', linewidth = 1)
    plt.text(data.index[-1],data[column].tail(1), column, color = 'gray', size = 'large', horizontalalignment = 'left')


plt.show()
